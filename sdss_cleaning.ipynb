# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib inline  

import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

from utils import *

# %% [markdown]
# # GAIA

# %%
data_path = '/media/snakoneczny/data/KiDS/KiDS.DR3.x.GAIA.x.SDSS.DR14.cols.csv'
kids_x_gaia_sdss = process_kids(data_path)
# Out:
# Data shape: (29297, 39)
# Droping NANs: 29297 left
# Removing flags: 10645 left
# Removing errors bigger than observations: 10643 left
# Removing limiting magnitudes: 10445 left
# Clean data shape: (10445, 49)

# %%
kids_x_gaia_sdss_clean = clean_sdss(kids_x_gaia_sdss)
# Out:
# Cleaning SDSS: 10061 left

# %%
print(np.unique(kids_x_gaia_sdss['CLASS'], return_counts=True))
# Out:
# (array(['GALAXY', 'QSO', 'STAR'], dtype=object), array([2176, 2672, 5597]))

# %%
print(np.unique(kids_x_gaia_sdss_clean['CLASS'], return_counts=True))
# Out:
# (array(['GALAXY', 'QSO', 'STAR'], dtype=object), array([2098, 2522, 5441]))

# %%
sns.set(style='ticks')
for c in ['STAR', 'GALAXY', 'QSO']:
    sns.distplot(kids_x_gaia_sdss.loc[kids_x_gaia_sdss['CLASS'] == c][MAG_GAAP_CALIB_UG], label=c, kde=False, rug=False,
                 hist_kws={'alpha': 0.5})
plt.legend()

# %%
sns.set(style='ticks')
for c in ['STAR', 'GALAXY', 'QSO']:
    sns.distplot(kids_x_gaia_sdss_clean.loc[kids_x_gaia_sdss_clean['CLASS'] == c][MAG_GAAP_CALIB_UG], label=c, kde=False,
                 rug=False, hist_kws={'alpha': 0.5})
plt.legend()

# %%
sns.set(style='ticks')
for c in ['STAR', 'GALAXY', 'QSO']:
    sns.distplot(kids_x_gaia_sdss.loc[kids_x_gaia_sdss['CLASS'] == c][MAG_GAAP_CALIB_UR], label=c, kde=False, rug=False,
                 hist_kws={'alpha': 0.5})
plt.legend()

# %%
sns.set(style='ticks')
for c in ['STAR', 'GALAXY', 'QSO']:
    sns.distplot(kids_x_gaia_sdss_clean.loc[kids_x_gaia_sdss_clean['CLASS'] == c][MAG_GAAP_CALIB_UR], label=c, kde=False, rug=False,
                 hist_kws={'alpha': 0.5})
plt.legend()

# %% [markdown]
# # KiDS

# %%
kids_x_sdss = process_kids('/media/snakoneczny/data/KiDS/KiDS.DR3.x.SDSS.DR14.cols.csv', with_colors=True)
# Out:
# Data shape: (91317, 44)
# Droping NANs: 91317 left
# Removing flags: 31908 left
# Removing errors bigger than observations: 31876 left
# Removing limiting magnitudes: 26239 left
# Clean KiDS shape: (26239, 54)

# %%
kids_x_sdss_clean = clean_sdss(kids_x_sdss)
# Out:
# Cleaning SDSS: 24023 left

# %%
print(np.unique(kids_x_sdss['CLASS'], return_counts=True))
# Out:
# (array(['GALAXY', 'QSO', 'STAR'], dtype=object), array([12509,  5284,  8446]))

# %%
print(np.unique(kids_x_sdss_clean['CLASS'], return_counts=True))
# Out:
# (array(['GALAXY', 'QSO', 'STAR'], dtype=object), array([12115,  4552,  7356]))

# %%
sns.set(style='ticks')
for c in ['STAR', 'GALAXY', 'QSO']:
    sns.distplot(kids_x_sdss.loc[kids_x_sdss['CLASS'] == c][MAG_GAAP_CALIB_UG], label=c,
                 kde=False, rug=False, hist_kws={'alpha': 0.5})
plt.legend()

# %%
sns.set(style='ticks')
for c in ['STAR', 'GALAXY', 'QSO']:
    sns.distplot(kids_x_sdss_clean.loc[kids_x_sdss_clean['CLASS'] == c][MAG_GAAP_CALIB_UG], label=c,
                 kde=False, rug=False, hist_kws={'alpha': 0.5})
plt.legend()

# %%
sns.set(style='ticks')
for c in ['STAR', 'GALAXY', 'QSO']:
    sns.distplot(kids_x_sdss.loc[kids_x_sdss['CLASS'] == c][MAG_GAAP_CALIB_UR], label=c,
                 kde=False, rug=False, hist_kws={'alpha': 0.5})
plt.legend()

# %%
sns.set(style='ticks')
for c in ['STAR', 'GALAXY', 'QSO']:
    sns.distplot(kids_x_sdss_clean.loc[kids_x_sdss_clean['CLASS'] == c][MAG_GAAP_CALIB_UR], label=c,
                 kde=False, rug=False, hist_kws={'alpha': 0.5})
plt.legend()

# %%
sns.set(style='ticks')
for b in BAND_COLUMNS:
    plt.figure()
    sns.distplot(kids_x_sdss[b], label='normal', kde=False, rug=False, hist_kws={'alpha': 0.5})
    sns.distplot(kids_x_sdss_clean[b], label='without ZWARNING', kde=False, rug=False, hist_kws={'alpha': 0.5})
    plt.legend()

# %%
sns.set(style='ticks')
for b in COLOR_COLUMNS:
    plt.figure()
    sns.distplot(kids_x_sdss[b], label='normal', kde=False, rug=False, hist_kws={'alpha': 0.5})
    sns.distplot(kids_x_sdss_clean[b], label='without ZWARNING', kde=False, rug=False, hist_kws={'alpha': 0.5})
    plt.legend()
