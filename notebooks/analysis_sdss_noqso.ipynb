# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib inline  

import sys
import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sys.path.append('..')
from data import *

# %%
import matplotlib as mpl
mpl.rcParams['figure.dpi']= 100

sns.set(style='ticks')
sns.set_palette('cubehelix')

# %% [markdown]
# # NO *_NOQSO

# %%
columns = COLUMNS_KIDS_ALL + COLUMNS_SDSS
kids_x_sdss = process_kids(os.path.join(DATA_PATH, 'KiDS/DR4/KiDS.DR4.x.SDSS.DR14.fits'), sdss_cleaning=False, columns=columns)
kids_x_sdss_clean = process_kids(os.path.join(DATA_PATH, 'KiDS/DR4/KiDS.DR4.x.SDSS.DR14.fits'), sdss_cleaning=True, columns=columns)
# Out:
# Data shape: (152244, 53)
# Droping NANs: 130777 (85.90%) left
# Data shape: (152244, 53)
# Droping NANs: 130777 (85.90%) left
# /mnt/home/snakoneczny/tools/anaconda3/envs/python3-gpu/lib/python3.7/site-packages/pandas/core/indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# Cleaning SDSS: 123416 left

# %%
sdss_cols = ['Z', 'Z_ERR', 'ZWARNING', 'Z_NOQSO', 'Z_ERR_NOQSO', 'ZWARNING_NOQSO']

# %%
kids_x_sdss[sdss_cols].describe()
# Out:
#                    Z          Z_ERR       ZWARNING        Z_NOQSO  \
# count  130777.000000  130777.000000  130777.000000  130777.000000
# mean        0.445061       0.042743       1.019201       0.192529
# std         0.674816       3.171078      16.229596       0.258071
# min        -0.011329      -6.000000       0.000000      -0.011447
# 25%         0.051542       0.000020       0.000000       0.000000
# 50%         0.223614       0.000066       0.000000       0.000000
# 75%         0.543708       0.000151       0.000000       0.470772
# max         7.012356    1023.314697     646.000000       1.002166
#
#          Z_ERR_NOQSO  ZWARNING_NOQSO
# count  130777.000000   130777.000000
# mean        0.004900        0.702861
# std         1.129710       15.151404
# min        -6.000000        0.000000
# 25%         0.000000        0.000000
# 50%         0.000016        0.000000
# 75%         0.000124        0.000000
# max       334.893219      646.000000

# %%
kids_x_sdss.loc[kids_x_sdss['CLASS'] == 'QSO', sdss_cols].describe()
# Out:
#                   Z         Z_ERR      ZWARNING       Z_NOQSO   Z_ERR_NOQSO  \
# count  16069.000000  16069.000000  16069.000000  16069.000000  16069.000000
# mean       1.844438      0.260483      2.308358      0.157813     -0.007220
# std        1.037087      8.748769     11.492475      0.247959      2.754400
# min        0.000938     -6.000000      0.000000     -0.011447     -6.000000
# 25%        1.042987      0.000205      0.000000      0.000000      0.000000
# 50%        1.909508      0.000389      0.000000      0.001269      0.000073
# 75%        2.450118      0.000667      0.000000      0.268255      0.000153
# max        7.012356   1023.314697    256.000000      1.001244    334.893219
#
#        ZWARNING_NOQSO
# count    16069.000000
# mean         1.445703
# std          5.033581
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          4.000000
# max        256.000000

# %%
kids_x_sdss.loc[kids_x_sdss['CLASS'] == 'STAR', sdss_cols].describe()
# Out:
#                   Z         Z_ERR      ZWARNING       Z_NOQSO   Z_ERR_NOQSO  \
# count  27856.000000  27856.000000  27856.000000  27856.000000  27856.000000
# mean       0.000177      0.019857      0.626580      0.000108      0.009706
# std        0.000474      0.602251      4.447204      0.000352      0.403242
# min       -0.004179     -1.000000      0.000000     -0.004179     -1.000000
# 25%       -0.000049      0.000011      0.000000      0.000000      0.000000
# 50%        0.000121      0.000026      0.000000      0.000000      0.000000
# 75%        0.000371      0.000074      0.000000      0.000159      0.000064
# max        0.004153     52.675541    260.000000      0.004153     39.780235
#
#        ZWARNING_NOQSO
# count    27856.000000
# mean         0.479861
# std          3.827020
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max        260.000000

# %%
kids_x_sdss.loc[(kids_x_sdss['CLASS'] == 'GALAXY'), sdss_cols].describe()
# Out:
#                   Z         Z_ERR  ZWARNING       Z_NOQSO   Z_ERR_NOQSO  \
# count  84728.000000  84728.000000   84728.0  84728.000000  84728.000000
# mean       0.325776      0.000284       0.0      0.258082      0.000165
# std        0.215532      0.044569       0.0      0.267353      0.027826
# min       -0.009760     -6.000000       0.0     -0.000813     -1.000000
# 25%        0.112110      0.000022       0.0      0.000000      0.000000
# 50%        0.322943      0.000062       0.0      0.219410      0.000030
# 75%        0.521533      0.000135       0.0      0.520923      0.000132
# max        1.002166      7.468226       0.0      1.002166      7.468226
#
#        ZWARNING_NOQSO
# count         84728.0
# mean              0.0
# std               0.0
# min               0.0
# 25%               0.0
# 50%               0.0
# 75%               0.0
# max               0.0

# %%
kids_x_sdss_clean[sdss_cols].describe()
# Out:
#                    Z          Z_ERR  ZWARNING        Z_NOQSO    Z_ERR_NOQSO  \
# count  123416.000000  123416.000000  123416.0  123416.000000  123416.000000
# mean        0.425095       0.006224       0.0       0.195419      -0.003534
# std         0.612095       0.677057       0.0       0.257451       0.280020
# min        -0.009760      -6.000000       0.0      -0.011447      -6.000000
# 25%         0.060790       0.000020       0.0       0.000000       0.000000
# 50%         0.226384       0.000059       0.0       0.000000       0.000008
# 75%         0.537231       0.000144       0.0       0.473975       0.000118
# max         7.010402     219.747314       0.0       1.002166      53.454880
#
#        ZWARNING_NOQSO
# count   123416.000000
# mean         0.112336
# std          0.660853
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          4.000000

# %% [markdown]
# # *_NOQSO cleaning

# %%
kids_x_sdss = process_kids('/media/snakoneczny/data/KiDS/DR4/KiDS.DR4.x.SDSS.DR14.fits', sdss_cleaning=False)
kids_x_sdss_clean = process_kids('/media/snakoneczny/data/KiDS/DR4/KiDS.DR4.x.SDSS.DR14.fits', sdss_cleaning=True)
# Out:
# Data shape: (152244, 50)
# Droping NANs: 130777 (85.90%) left
# Removing errors bigger than 1: 129111 (84.81%) left
# Removing GAAP flags: 129111 left
# Removing IMA flags: 128675 (84.52%) left
# Data shape: (152244, 50)
# Droping NANs: 130777 (85.90%) left
# Removing errors bigger than 1: 129111 (84.81%) left
# Removing GAAP flags: 129111 left
# Removing IMA flags: 128675 (84.52%) left
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# Cleaning SDSS: 122363 left

# %%
sdss_cols = ['Z', 'Z_ERR', 'ZWARNING', 'Z_NOQSO', 'Z_ERR_NOQSO', 'ZWARNING_NOQSO']

# %%
kids_x_sdss[sdss_cols].describe()
# Out:
#                    Z          Z_ERR       ZWARNING        Z_NOQSO  \
# count  128675.000000  128675.000000  128675.000000  128675.000000
# mean        0.444901       0.041225       1.010725       0.191574
# std         0.672839       3.190578      16.326870       0.257510
# min        -0.011329      -6.000000       0.000000      -0.011447
# 25%         0.052789       0.000020       0.000000       0.000000
# 50%         0.223035       0.000065       0.000000       0.000000
# 75%         0.543032       0.000150       0.000000       0.469169
# max         7.012356    1023.314697     646.000000       1.002166
#
#          Z_ERR_NOQSO  ZWARNING_NOQSO
# count  128675.000000   128675.000000
# mean        0.004663        0.698978
# std         1.137789       15.264976
# min        -6.000000        0.000000
# 25%         0.000000        0.000000
# 50%         0.000014        0.000000
# 75%         0.000122        0.000000
# max       334.893219      646.000000

# %%
kids_x_sdss.loc[kids_x_sdss['CLASS'] == 'QSO', sdss_cols].describe()
# Out:
#                   Z         Z_ERR      ZWARNING       Z_NOQSO   Z_ERR_NOQSO  \
# count  15853.000000  15853.000000  15853.000000  15853.000000  15853.000000
# mean       1.841618      0.249794      2.254589      0.156175     -0.007396
# std        1.027087      8.791291     11.419629      0.246446      2.772919
# min        0.000938     -6.000000      0.000000     -0.011447     -6.000000
# 25%        1.041832      0.000204      0.000000      0.000000      0.000000
# 50%        1.916959      0.000388      0.000000      0.001222      0.000071
# 75%        2.450118      0.000662      0.000000      0.265660      0.000151
# max        7.012356   1023.314697    256.000000      1.001244    334.893219
#
#        ZWARNING_NOQSO
# count    15853.000000
# mean         1.422002
# std          5.059642
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          4.000000
# max        256.000000

# %%
kids_x_sdss.loc[kids_x_sdss['CLASS'] == 'STAR', sdss_cols].describe()
# Out:
#                   Z         Z_ERR      ZWARNING       Z_NOQSO   Z_ERR_NOQSO  \
# count  27161.000000  27161.000000  27161.000000  27161.000000  27161.000000
# mean       0.000179      0.018638      0.609698      0.000108      0.008884
# std        0.000471      0.600455      4.490652      0.000347      0.397354
# min       -0.004179     -1.000000      0.000000     -0.004179     -1.000000
# 25%       -0.000048      0.000011      0.000000      0.000000      0.000000
# 50%        0.000122      0.000025      0.000000      0.000000      0.000000
# 75%        0.000373      0.000071      0.000000      0.000155      0.000061
# max        0.004153     52.675541    260.000000      0.004153     39.780235
#
#        ZWARNING_NOQSO
# count    27161.000000
# mean         0.463385
# std          3.863560
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max        260.000000

# %%
kids_x_sdss.loc[kids_x_sdss['CLASS'] == 'GALAXY', sdss_cols].describe()
# Out:
#                   Z         Z_ERR      ZWARNING       Z_NOQSO   Z_ERR_NOQSO  \
# count  85661.000000  85661.000000  85661.000000  85661.000000  85661.000000
# mean       0.327426      0.009788      0.907683      0.258835      0.005556
# std        0.217429      0.930352     19.223625      0.268310      0.686740
# min       -0.011329     -6.000000      0.000000     -0.011329     -1.000000
# 25%        0.112168      0.000022      0.000000      0.000000      0.000000
# 50%        0.325143      0.000063      0.000000      0.218945      0.000031
# 75%        0.523583      0.000137      0.000000      0.522216      0.000133
# max        1.002166    176.504379    646.000000      1.002166    154.690872
#
#        ZWARNING_NOQSO
# count    85661.000000
# mean         0.639871
# std         18.451058
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max        646.000000

# %%
kids_x_sdss_clean[sdss_cols].describe()
# Out:
#                    Z          Z_ERR  ZWARNING        Z_NOQSO    Z_ERR_NOQSO  \
# count  122363.000000  122363.000000  122363.0  122363.000000  122363.000000
# mean        0.377225       0.005514       0.0       0.193402      -0.003640
# std         0.634549       0.669030       0.0       0.256707       0.279871
# min        -0.004136      -6.000000       0.0      -0.011447      -6.000000
# 25%         0.000000       0.000000       0.0       0.000000       0.000000
# 50%         0.000475       0.000042       0.0       0.000000       0.000007
# 75%         0.535579       0.000140       0.0       0.471244       0.000117
# max         7.010402     219.747314       0.0       1.002166      53.454880
#
#        ZWARNING_NOQSO
# count   122363.000000
# mean         0.112322
# std          0.660813
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          4.000000
