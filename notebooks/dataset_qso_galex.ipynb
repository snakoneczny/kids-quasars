# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib inline 

import sys
import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sys.path.append('..')
from env_config import DATA_PATH
from utils import *
from data import *
from plotting import *

# %%
import matplotlib as mpl
mpl.rcParams['figure.dpi']= 100

sns.set(style='ticks')
sns.set_palette('cubehelix')

# %%
galex = read_fits_to_pandas(os.path.join(DATA_PATH, 'QSO/xdqsozcat_galex_ukidss_wise_p20.fits'),
                            columns=['ID', 'PQSO'])

# %%
galex_x_kids = read_fits_to_pandas(os.path.join(DATA_PATH, 'KiDS/DR4/KiDS.DR4.x.QSO.GALEX.fits'),
                            columns=['ID_1', 'PQSO'])

# %%
plt.hist(galex['PQSO'], bins=20, log=True)
# Out:
# (array([ 445690.,  339818.,  271245.,  226897.,  193671.,  169347.,
#          151437.,  137665.,  127234.,  120071.,  114264.,  110664.,
#          109810.,  109522.,  112594.,  119488.,  132446.,  158612.,
#          220692., 2166269.]),
#  array([0.20000005, 0.24000005, 0.28000005, 0.32000004, 0.36000004,
#         0.40000004, 0.44000004, 0.48000003, 0.52000003, 0.56000003,
#         0.60000003, 0.64000002, 0.68000002, 0.72000002, 0.76000002,
#         0.80000001, 0.84000001, 0.88000001, 0.92000001, 0.96      ,
#         1.        ]),
#  <a list of 20 Patch objects>)
# The history saving thread hit an unexpected error (OperationalError('database is locked')).History will not be written to the database.

# %%
plt.hist(galex_x_kids['PQSO'], bins=20, log=True)
# Out:
# (array([10193.,  7428.,  5896.,  4782.,  4147.,  3626.,  3117.,  2760.,
#          2568.,  2416.,  2259.,  2320.,  2176.,  2202.,  2294.,  2401.,
#          2772.,  3325.,  4715., 44842.]),
#  array([0.20000158, 0.2400015 , 0.28000142, 0.32000134, 0.36000126,
#         0.40000118, 0.4400011 , 0.48000102, 0.52000095, 0.56000087,
#         0.60000079, 0.64000071, 0.68000063, 0.72000055, 0.76000047,
#         0.80000039, 0.84000032, 0.88000024, 0.92000016, 0.96000008,
#         1.        ]),
#  <a list of 20 Patch objects>)
